# %%
import pickle

with open('outfile_april_12_pre', 'rb') as fp:
    baseball_data1 = pickle.load(fp)
    
with open('outfile_april_12_post', 'rb') as fp:
    baseball_data2 = pickle.load(fp)

# %%
baseball_data2
# Out:
#    game.away.abbr  game.away.current_pitcher.era  \
# 0             BAL                            NaN
# 1             CWS                            NaN
# 2             MIL                            NaN
# 3             COL                            NaN
# 4             PIT                            NaN
# 5              TB                            NaN
# 6             LAA                          2.455
# 7              SD                            NaN
# 8             HOU                            NaN
# 9             CLE                            NaN
# 10            PHI                            NaN
# 11            NYM                            NaN
# 12            OAK                            NaN
# 13            DET                            NaN
#
#    game.away.current_pitcher.first_name          game.away.current_pitcher.id  \
# 0                                   NaN                                   NaN
# ...

# %%
baseball_data1.shape
# Out:
# (14, 67)
