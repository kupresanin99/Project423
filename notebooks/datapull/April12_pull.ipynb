# %%
import http.client
import json
import pandas as pd
from pandas.io.json import json_normalize

pd.set_option('display.max_columns', None)

month = 4
day = 12

conn = http.client.HTTPSConnection("api.sportradar.us")

conn.request("GET", 
             "/mlb/trial/v6.5/en/games/2019/{0}/{1}/boxscore.json?api_key=bw84ac36vu34rdk5vkkh4psx".format(month, day))

res = conn.getresponse()
data = res.read()

baseball_data = []
baseball_data.append(data.decode("utf-8"))

baseball_json = []
baseball_json.append(json.loads(baseball_data[0]))
del baseball_json[0]['_comment']
    
joe = json_normalize(baseball_json)
joe = joe.drop(columns=['league.alias', 'league.date',
                 'league.id', 'league.name'])

joey = json_normalize(joe.iloc[0,0])

# %%
joey
# Out:
#    game.attendance game.away.abbr  game.away.errors  \
# 0            31906            PIT                 1
# 1            38200            LAD                 2
# 2            29727            COL                 0
# 3             8374            OAK                 1
# 4            11192            MIA                 0
# 5            24015            NYM                 0
# 6            36510            TOR                 1
# 7            10231            SEA                 2
# 8            13910            CLE                 1
# 9            15449             SD                 1
#
#                                     game.away.events  game.away.hits  \
# 0                                                NaN               5
# 1  [{'hitter_outcome': 'oSF', 'inning_half': 'T',...              10
# 2                                                NaN               3
# 3  [{'hitter_outcome': 'aHR', 'inning_half': 'T',...              11
# 4                                                NaN               5
# 5  [{'hitter_outcome': 'aHR', 'inning_half': 'T',...               7
# 6  [{'hitter_outcome': 'aHR', 'inning_half': 'T',...               8
# 7  [{'hitter_outcome': 'aHR', 'inning_half': 'T',...              12
# 8  [{'hitter_outcome': 'aS', 'inning_half': 'T', ...              11
# 9  [{'hitter_outcome': 'aHR', 'inning_half': 'T',...               8
#
#                            game.away.id  game.away.loss game.away.market  \
# 0  481dfe7e-5dab-46ab-a49f-9dcc2b6e2cfd               4       Pittsburgh
# 1  ef64da7f-cfaf-4300-87b0-9313386b977c               5      Los Angeles
# 2  29dd9a87-5bcc-4774-80c3-7f50d985068b               9         Colorado
# 3  27a59d3b-ff7c-48ea-b016-4798f560f5e1               8          Oakland
# 4  03556285-bdbb-4576-a06d-42f71f46ddc5               9            Miami
# 5  f246a5e5-afdb-479c-9aaa-c68beeda7af6               4         New York
# 6  1d678440-b4b1-4954-9b39-70afb3ebbcfa               8          Toronto
# 7  43a39081-52b4-4f93-ad29-da7f329ea960               2          Seattle
# 8  80715d0d-0d2a-450f-a970-1b9a3b18c7e7               4        Cleveland
# 9  d52d5339-cbdd-43f3-9dfa-a42fd588b9a3               5        San Diego
#
#   game.away.name  game.away.probable_pitcher.era  \
# 0        Pirates                           0.000
# 1        Dodgers                           6.750
# 2        Rockies                           5.684
# 3      Athletics                           4.091
# 4        Marlins                           6.097
# 5           Mets                           0.871
# 6      Blue Jays                           1.636
# 7       Mariners                           2.919
# 8        Indians                           3.375
# 9         Padres                             NaN
#
#   game.away.probable_pitcher.first_name         game.away.probable_pitcher.id  \
# 0                                Joseph  9c12832b-c487-40d4-915b-e44097632d7c
# 1                                Walker  3703319e-ec2e-4db7-9e86-59589e233f95
# 2                              Jonathan  106c933c-0203-4e5a-bd06-f8bc420b9b9f
# 3                                 Aaron  17041232-04c9-45ea-8a8c-575e87a3f774
# 4                                 Pablo  2d8de314-4980-4f1a-97b5-279261ceb111
# 5                                Steven  03fda22a-f8a3-45e8-80dc-bf8190a22020
# 6                                 Aaron  49be9f8e-db22-487e-8487-34c1eb01919b
# 7                               Michael  7b54341a-7d39-4ea6-8b94-19ef145c8fba
# 8                                 Shane  5a6d40fb-f37a-415d-bae6-83fd66bb3322
# 9                                 Pedro  0d4b4a6e-7b39-41b5-8f8e-843b7dea0857
#
#   game.away.probable_pitcher.jersey_number  \
# 0                                       59
# 1                                       21
# 2                                       55
# 3                                       35
# 4                                       49
# 5                                       32
# 6                                       41
# 7                                        8
# 8                                       57
# 9                                       68
#
#   game.away.probable_pitcher.last_name  game.away.probable_pitcher.loss  \
# 0                             Musgrove                              0.0
# 1                              Buehler                              0.0
# 2                                 Gray                              2.0
# 3                               Brooks                              1.0
# 4                                Lopez                              1.0
# 5                                 Matz                              0.0
# 6                              Sanchez                              1.0
# 7                                Leake                              0.0
# 8                               Bieber                              0.0
# 9                                Avila                              NaN
#
#   game.away.probable_pitcher.preferred_name  game.away.probable_pitcher.win  \
# 0                                       Joe                             1.0
# 1                                    Walker                             1.0
# 2                                       Jon                             0.0
# 3                                     Aaron                             1.0
# 4                                     Pablo                             1.0
# 5                                    Steven                             0.0
# 6                                     Aaron                             1.0
# 7                                      Mike                             2.0
# 8                                     Shane                             0.0
# 9                                     Pedro                             NaN
#
#    game.away.runs                                  game.away.scoring  \
# 0               0  [{'runs': 0, 'sequence': 1, 'errors': 0, 'numb...
# 1               7  [{'runs': 1, 'sequence': 1, 'errors': 0, 'numb...
# 2               0  [{'runs': 0, 'sequence': 1, 'errors': 0, 'numb...
# 3               8  [{'runs': 0, 'sequence': 1, 'errors': 0, 'numb...
# 4               0  [{'runs': 0, 'sequence': 1, 'errors': 0, 'numb...
# 5               6  [{'runs': 0, 'sequence': 1, 'errors': 0, 'numb...
# 6               6  [{'runs': 0, 'sequence': 1, 'errors': 0, 'numb...
# 7               7  [{'runs': 0, 'sequence': 1, 'errors': 0, 'numb...
# 8               4  [{'runs': 1, 'sequence': 1, 'errors': 0, 'numb...
# 9               7  [{'runs': 0, 'sequence': 1, 'errors': 0, 'numb...
#
#    game.away.starting_pitcher.era game.away.starting_pitcher.first_name  \
# 0                           0.000                                Joseph
# 1                           6.750                                Walker
# 2                           5.684                              Jonathan
# 3                           4.091                                 Aaron
# 4                           6.097                                 Pablo
# 5                           0.871                                Steven
# 6                           1.636                                 Aaron
# 7                           2.919                               Michael
# 8                           3.375                                 Shane
# 9                             NaN                                 Pedro
#
#           game.away.starting_pitcher.id  \
# 0  9c12832b-c487-40d4-915b-e44097632d7c
# 1  3703319e-ec2e-4db7-9e86-59589e233f95
# 2  106c933c-0203-4e5a-bd06-f8bc420b9b9f
# 3  17041232-04c9-45ea-8a8c-575e87a3f774
# 4  2d8de314-4980-4f1a-97b5-279261ceb111
# 5  03fda22a-f8a3-45e8-80dc-bf8190a22020
# 6  49be9f8e-db22-487e-8487-34c1eb01919b
# 7  7b54341a-7d39-4ea6-8b94-19ef145c8fba
# 8  5a6d40fb-f37a-415d-bae6-83fd66bb3322
# 9  0d4b4a6e-7b39-41b5-8f8e-843b7dea0857
#
#   game.away.starting_pitcher.jersey_number  \
# 0                                       59
# 1                                       21
# 2                                       55
# 3                                       35
# 4                                       49
# 5                                       32
# 6                                       41
# 7                                        8
# 8                                       57
# 9                                       68
#
#   game.away.starting_pitcher.last_name  game.away.starting_pitcher.loss  \
# 0                             Musgrove                              0.0
# 1                              Buehler                              0.0
# 2                                 Gray                              2.0
# 3                               Brooks                              1.0
# 4                                Lopez                              1.0
# 5                                 Matz                              0.0
# 6                              Sanchez                              1.0
# 7                                Leake                              0.0
# 8                               Bieber                              0.0
# 9                                Avila                              NaN
#
#   game.away.starting_pitcher.preferred_name  game.away.starting_pitcher.win  \
# 0                                       Joe                             1.0
# 1                                    Walker                             1.0
# 2                                       Jon                             0.0
# 3                                     Aaron                             1.0
# 4                                     Pablo                             1.0
# 5                                    Steven                             0.0
# 6                                     Aaron                             1.0
# 7                                      Mike                             2.0
# 8                                     Shane                             0.0
# 9                                     Pedro                             NaN
#
#    game.away.win                        game.away_team game.broadcast.network  \
# 0              6  481dfe7e-5dab-46ab-a49f-9dcc2b6e2cfd            MLB Network
# 1              8  ef64da7f-cfaf-4300-87b0-9313386b977c            MLB Network
# 2              3  29dd9a87-5bcc-4774-80c3-7f50d985068b                NBCS-BA
# 3              8  27a59d3b-ff7c-48ea-b016-4798f560f5e1                   MASN
# 4              3  03556285-bdbb-4576-a06d-42f71f46ddc5                  FS-OH
# 5              7  f246a5e5-afdb-479c-9aaa-c68beeda7af6                  FS-SE
# 6              4  1d678440-b4b1-4954-9b39-70afb3ebbcfa                   NESN
# 7             12  43a39081-52b4-4f93-ad29-da7f329ea960                  FS-KC
# 8              7  80715d0d-0d2a-450f-a970-1b9a3b18c7e7                 FS-DET
# 9              8  d52d5339-cbdd-43f3-9dfa-a42fd588b9a3                  FS-AZ
#
#   game.coverage game.day_night  game.double_header game.duration  \
# 0          full              N               False          2:38
# 1          full              D               False          3:12
# 2          full              N               False          2:34
# 3          full              D               False          2:50
# 4          full              D               False          2:51
# 5          full              N               False          3:14
# 6          full              N               False          3:21
# 7          full              D               False          3:27
# 8          full              D               False          2:47
# 9          full              N               False          3:13
#
#    game.final.inning game.final.inning_half  game.game_number game.home.abbr  \
# 0                  9                      T                 1            CHC
# 1                  9                      T                 1            STL
# 2                  9                      T                 1             SF
# 3                  9                      B                 1            BAL
# 4                  9                      T                 1            CIN
# 5                  9                      B                 1            ATL
# 6                  9                      B                 1            BOS
# 7                 10                      B                 1             KC
# 8                  9                      B                 1            DET
# 9                  9                      B                 1            ARI
#
#    game.home.errors                                   game.home.events  \
# 0                 0  [{'hitter_outcome': 'aSAD2', 'inning_half': 'B...
# 1                 0  [{'hitter_outcome': 'aHBP', 'inning_half': 'B'...
# 2                 0  [{'hitter_outcome': 'aHR', 'inning_half': 'B',...
# 3                 2  [{'hitter_outcome': 'aHR', 'inning_half': 'B',...
# 4                 0  [{'hitter_outcome': 'aS', 'inning_half': 'B', ...
# 5                 0  [{'hitter_outcome': 'aT', 'inning_half': 'B', ...
# 6                 0  [{'hitter_outcome': 'aD', 'inning_half': 'B', ...
# 7                 0  [{'hitter_outcome': 'aHR', 'inning_half': 'B',...
# 8                 0                                                NaN
# 9                 0  [{'hitter_outcome': 'aS', 'inning_half': 'B', ...
#
#    game.home.hits                          game.home.id  game.home.loss  \
# 0               5  55714da8-fcaf-4574-8443-59bfb511a524               8
# 1              10  44671792-dc02-4fdd-a5ad-f5f17edaa9d7               5
# 2               6  a7723160-10b7-4277-a309-d8dd95a8ae65               9
# 3               4  75729d34-bca7-4a0f-b3df-6f26c6ad3719               7
# 4              10  c874a065-c115-4e7d-b0f0-235584fb0e6f               8
# 5               9  12079497-e414-450a-8bf2-29f91de646bf               4
# 6               8  93941372-eb4c-4c40-aced-fe3267174393               9
# 7               8  833a51a9-0d84-410f-bd77-da08c3e5e26e               9
# 8               3  575c19b7-4052-41c2-9f0a-1c5813d02f99               4
# 9               8  25507be1-6a68-4267-bd82-e097d94b359b               6
#
#   game.home.market game.home.name  game.home.probable_pitcher.era  \
# 0          Chicago           Cubs                          10.286
# 1        St. Louis      Cardinals                           1.543
# 2    San Francisco         Giants                           2.793
# 3        Baltimore        Orioles                           7.364
# 4       Cincinnati           Reds                           2.893
# 5          Atlanta         Braves                           0.000
# 6           Boston        Red Sox                           8.100
# 7      Kansas City         Royals                           4.091
# 8          Detroit         Tigers                           4.091
# 9          Arizona   Diamondbacks                           6.545
#
#   game.home.probable_pitcher.first_name         game.home.probable_pitcher.id  \
# 0                                  José  b1e3b804-0022-40bc-8f53-8c82ee4eb1b9
# 1                               Michael  db6ced3d-7838-4a7c-92a5-50d0b63dac3b
# 2                               Jeffrey  c8f30e7e-118c-4a16-b899-8ef2cfc75f02
# 3                                 Dylan  4ad7af6c-4949-4b11-a311-0997c9e28491
# 4                                 Sonny  b004cc6c-f00c-4b5d-917a-ee1abf92179d
# 5                                 Kevin  cef2e01f-1349-4e31-bf1e-757ae8cb6bc6
# 6                                Nathan  6dd571bc-b26c-4efc-87da-7b501c96faf1
# 7                                 Jorge  b9766398-e982-43a6-a3a0-f7f8e24061c6
# 8                               Spencer  6e6497ec-cf68-47e3-a4d7-5b576b2e7418
# 9                               Zachary  4dabf1e0-871d-40ac-b522-4fd93af6b54d
#
#   game.home.probable_pitcher.jersey_number  \
# 0                                       62
# 1                                       52
# 2                                       29
# 3                                       37
# 4                                       54
# 5                                       45
# 6                                       17
# 7                                       28
# 8                                       56
# 9                                       52
#
#   game.home.probable_pitcher.last_name  game.home.probable_pitcher.loss  \
# 0                             Quintana                                1
# 1                                Wacha                                0
# 2                           Samardzija                                0
# 3                                Bundy                                0
# 4                                 Gray                                2
# 5                              Gausman                                0
# 6                              Eovaldi                                0
# 7                                López                                1
# 8                             Turnbull                                1
# 9                               Godley                                1
#
#   game.home.probable_pitcher.preferred_name  game.home.probable_pitcher.win  \
# 0                                      José                               0
# 1                                   Michael                               0
# 2                                      Jeff                               0
# 3                                     Dylan                               0
# 4                                     Sonny                               0
# 5                                     Kevin                               1
# 6                                    Nathan                               0
# 7                                     Jorge                               0
# 8                                   Spencer                               0
# 9                                      Zack                               1
#
#    game.home.runs                                  game.home.scoring  \
# 0               2  [{'runs': 0, 'sequence': 1, 'errors': 0, 'numb...
# 1              11  [{'runs': 0, 'sequence': 1, 'errors': 0, 'numb...
# 2               1  [{'runs': 0, 'sequence': 1, 'errors': 0, 'numb...
# 3               5  [{'runs': 1, 'sequence': 1, 'errors': 0, 'numb...
# 4               5  [{'runs': 0, 'sequence': 1, 'errors': 0, 'numb...
# 5               3  [{'runs': 1, 'sequence': 1, 'errors': 0, 'numb...
# 6               7  [{'runs': 0, 'sequence': 1, 'errors': 0, 'numb...
# 7               6  [{'runs': 0, 'sequence': 1, 'errors': 0, 'numb...
# 8               0  [{'runs': 0, 'sequence': 1, 'errors': 0, 'numb...
# 9               6  [{'runs': 1, 'sequence': 1, 'errors': 0, 'numb...
#
#    game.home.starting_pitcher.era game.home.starting_pitcher.first_name  \
# 0                          10.286                                  José
# 1                           1.543                               Michael
# 2                           2.793                               Jeffrey
# 3                           7.364                                 Dylan
# 4                           2.893                                 Sonny
# 5                           0.000                                 Kevin
# 6                           8.100                                Nathan
# 7                           4.091                                 Jorge
# 8                           4.091                               Spencer
# 9                           6.545                               Zachary
#
#           game.home.starting_pitcher.id  \
# 0  b1e3b804-0022-40bc-8f53-8c82ee4eb1b9
# 1  db6ced3d-7838-4a7c-92a5-50d0b63dac3b
# 2  c8f30e7e-118c-4a16-b899-8ef2cfc75f02
# 3  4ad7af6c-4949-4b11-a311-0997c9e28491
# 4  b004cc6c-f00c-4b5d-917a-ee1abf92179d
# 5  cef2e01f-1349-4e31-bf1e-757ae8cb6bc6
# 6  6dd571bc-b26c-4efc-87da-7b501c96faf1
# 7  b9766398-e982-43a6-a3a0-f7f8e24061c6
# 8  6e6497ec-cf68-47e3-a4d7-5b576b2e7418
# 9  4dabf1e0-871d-40ac-b522-4fd93af6b54d
#
#   game.home.starting_pitcher.jersey_number  \
# 0                                       62
# 1                                       52
# 2                                       29
# 3                                       37
# 4                                       54
# 5                                       45
# 6                                       17
# 7                                       28
# 8                                       56
# 9                                       52
#
#   game.home.starting_pitcher.last_name  game.home.starting_pitcher.loss  \
# 0                             Quintana                                1
# 1                                Wacha                                0
# 2                           Samardzija                                0
# 3                                Bundy                                0
# 4                                 Gray                                2
# 5                              Gausman                                0
# 6                              Eovaldi                                0
# 7                                López                                1
# 8                             Turnbull                                1
# 9                               Godley                                1
#
#   game.home.starting_pitcher.preferred_name  game.home.starting_pitcher.win  \
# 0                                      José                               0
# 1                                   Michael                               0
# 2                                      Jeff                               0
# 3                                     Dylan                               0
# 4                                     Sonny                               0
# 5                                     Kevin                               1
# 6                                    Nathan                               0
# 7                                     Jorge                               0
# 8                                   Spencer                               0
# 9                                      Zack                               1
#
#    game.home.win                        game.home_team  \
# 0              3  55714da8-fcaf-4574-8443-59bfb511a524
# 1              7  44671792-dc02-4fdd-a5ad-f5f17edaa9d7
# 2              4  a7723160-10b7-4277-a309-d8dd95a8ae65
# 3              5  75729d34-bca7-4a0f-b3df-6f26c6ad3719
# 4              3  c874a065-c115-4e7d-b0f0-235584fb0e6f
# 5              7  12079497-e414-450a-8bf2-29f91de646bf
# 6              3  93941372-eb4c-4c40-aced-fe3267174393
# 7              2  833a51a9-0d84-410f-bd77-da08c3e5e26e
# 8              8  575c19b7-4052-41c2-9f0a-1c5813d02f99
# 9              6  25507be1-6a68-4267-bd82-e097d94b359b
#
#                                 game.id  \
# 0  7e16f8e0-71ac-4f50-933a-552960e05f3a
# 1  e20640e7-d258-460e-9a24-3bd0b58cf5d7
# 2  cd9e5776-516f-48bc-986b-70ca8348f018
# 3  873bd2c7-82a8-45de-8209-849e2a25ab94
# 4  79e92065-f7d0-47da-ae67-0ccebc995d9b
# 5  f199dc81-b887-490e-94c5-1e97ef2172d0
# 6  95ea0f5c-6634-408b-a38f-ee839bcef516
# 7  7a5097a5-270c-49cb-8717-fb669a9ebf48
# 8  051bf7dc-a431-43b8-a9be-840f14c53146
# 9  35535fd1-8284-42a6-8ee9-84efa37d8c33
#
#                             game.pitching.blown_save  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  [{'jersey_number': '51', 'status': 'A', 'first...
# 7  [{'jersey_number': '26', 'status': 'A', 'first...
# 8                                                NaN
# 9  [{'jersey_number': '57', 'status': 'A', 'first...
#
#                                   game.pitching.hold  \
# 0  [{'jersey_number': '41', 'status': 'A', 'first...
# 1  [{'jersey_number': '30', 'status': 'A', 'first...
# 2  [{'jersey_number': '56', 'status': 'A', 'first...
# 3  [{'jersey_number': '62', 'status': 'A', 'first...
# 4                                                NaN
# 5  [{'jersey_number': '27', 'status': 'A', 'first...
# 6  [{'jersey_number': '48', 'status': 'A', 'first...
# 7  [{'jersey_number': '43', 'status': 'A', 'first...
# 8                                                NaN
# 9  [{'jersey_number': '17', 'status': 'A', 'first...
#
#    game.pitching.loss.blown_save game.pitching.loss.first_name  \
# 0                              0                        Joseph
# 1                              0                         Pedro
# 2                              0                      Jonathan
# 3                              0                         Dylan
# 4                              0                         Pablo
# 5                              0                         Kevin
# 6                              1                       Kenneth
# 7                              0                         Glenn
# 8                              0                       Spencer
# 9                              1                        Archie
#
#    game.pitching.loss.hold                 game.pitching.loss.id  \
# 0                        1  9c12832b-c487-40d4-915b-e44097632d7c
# 1                        2  17f72cd8-4d7e-407a-8960-06ba2478b323
# 2                        0  106c933c-0203-4e5a-bd06-f8bc420b9b9f
# 3                        0  4ad7af6c-4949-4b11-a311-0997c9e28491
# 4                        0  2d8de314-4980-4f1a-97b5-279261ceb111
# 5                        0  cef2e01f-1349-4e31-bf1e-757ae8cb6bc6
# 6                        0  48347189-837d-4453-9e54-d3be3b9fc639
# 7                        0  3e007eed-c69d-4299-aacc-2d8516b07caf
# 8                        0  6e6497ec-cf68-47e3-a4d7-5b576b2e7418
# 9                        2  4a745f36-bec0-47d9-bdf6-6bac2ea84aeb
#
#   game.pitching.loss.jersey_number game.pitching.loss.last_name  \
# 0                               59                     Musgrove
# 1                               52                         Báez
# 2                               55                         Gray
# 3                               37                        Bundy
# 4                               49                        Lopez
# 5                               45                      Gausman
# 6                               51                        Giles
# 7                               57                     Sparkman
# 8                               56                     Turnbull
# 9                               25                      Bradley
#
#    game.pitching.loss.loss game.pitching.loss.position  \
# 0                        1                           P
# 1                        1                           P
# 2                        3                           P
# 3                        1                           P
# 4                        2                           P
# 5                        1                           P
# 6                        1                           P
# 7                        1                           P
# 8                        2                           P
# 9                        1                           P
#
#   game.pitching.loss.preferred_name game.pitching.loss.primary_position  \
# 0                               Joe                                  SP
# 1                             Pedro                                  RP
# 2                               Jon                                  SP
# 3                             Dylan                                  SP
# 4                             Pablo                                  SP
# 5                             Kevin                                  SP
# 6                               Ken                                  RP
# 7                             Glenn                                  RP
# 8                           Spencer                                  SP
# 9                            Archie                                  RP
#
#    game.pitching.loss.save game.pitching.loss.status  game.pitching.loss.win  \
# 0                        0                         A                       1
# 1                        0                         A                       0
# 2                        0                         A                       0
# 3                        0                         A                       0
# 4                        0                         A                       1
# 5                        0                         A                       1
# 6                        3                         A                       0
# 7                        0                         A                       0
# 8                        0                         A                       0
# 9                        0                         A                       0
#
#    game.pitching.save.blown_save game.pitching.save.first_name  \
# 0                            0.0                         Pedro
# 1                            NaN                           NaN
# 2                            0.0                       William
# 3                            1.0                         Blake
# 4                            NaN                           NaN
# 5                            0.0                         Edwin
# 6                            NaN                           NaN
# 7                            0.0                        Connor
# 8                            NaN                           NaN
# 9                            0.0                       Anthony
#
#    game.pitching.save.hold                 game.pitching.save.id  \
# 0                      0.0  d0772dfd-1d25-4baa-8e21-9633433d4976
# 1                      NaN                                   NaN
# 2                      0.0  19a3dd28-85dd-4ae0-969e-f4f33419ea5b
# 3                      0.0  abf9a77c-6b7f-40f8-a0ea-df8353ae7a8b
# 4                      NaN                                   NaN
# 5                      0.0  26db575b-359f-40b1-92c8-dfc549b72a25
# 6                      NaN                                   NaN
# 7                      0.0  be05afd0-72d2-424b-9150-71d519ba395f
# 8                      NaN                                   NaN
# 9                      3.0  a1ac8596-20b6-496b-aea5-0d7678cb37ec
#
#   game.pitching.save.jersey_number game.pitching.save.last_name  \
# 0                               46                        Strop
# 1                              NaN                          NaN
# 2                               13                        Smith
# 3                               39                      Treinen
# 4                              NaN                          NaN
# 5                               39                         Díaz
# 6                              NaN                          NaN
# 7                               54                      Sadzeck
# 8                              NaN                          NaN
# 9                               58                    Wingenter
#
#    game.pitching.save.loss game.pitching.save.position  \
# 0                      1.0                           P
# 1                      NaN                         NaN
# 2                      0.0                           P
# 3                      1.0                           P
# 4                      NaN                         NaN
# 5                      0.0                           P
# 6                      NaN                         NaN
# 7                      0.0                           P
# 8                      NaN                         NaN
# 9                      0.0                           P
#
#   game.pitching.save.preferred_name game.pitching.save.primary_position  \
# 0                             Pedro                                  RP
# 1                               NaN                                 NaN
# 2                              Will                                  RP
# 3                             Blake                                  RP
# 4                               NaN                                 NaN
# 5                             Edwin                                  RP
# 6                               NaN                                 NaN
# 7                            Connor                                  RP
# 8                               NaN                                 NaN
# 9                              Trey                                  RP
#
#    game.pitching.save.save game.pitching.save.status  game.pitching.save.win  \
# 0                      1.0                         A                     0.0
# 1                      NaN                       NaN                     NaN
# 2                      4.0                         A                     0.0
# 3                      4.0                         A                     0.0
# 4                      NaN                       NaN                     NaN
# 5                      5.0                         A                     0.0
# 6                      NaN                       NaN                     NaN
# 7                      1.0                         A                     0.0
# 8                      NaN                       NaN                     NaN
# 9                      1.0                         A                     0.0
#
#    game.pitching.win.blown_save game.pitching.win.first_name  \
# 0                             0                         José
# 1                             0                     Giovanny
# 2                             0                      Jeffrey
# 3                             0                        Aaron
# 4                             0                       Robert
# 5                             0                       Steven
# 6                             0                       Marcus
# 7                             0                      Brandon
# 8                             0                        Shane
# 9                             0                        Craig
#
#    game.pitching.win.hold                  game.pitching.win.id  \
# 0                       1  b1e3b804-0022-40bc-8f53-8c82ee4eb1b9
# 1                       0  07b26fab-24c4-4a02-9995-36f9cb5352d8
# 2                       0  c8f30e7e-118c-4a16-b899-8ef2cfc75f02
# 3                       0  17041232-04c9-45ea-8a8c-575e87a3f774
# 4                       0  fba71c66-344e-44b7-a5b8-1b67f6a3c767
# 5                       0  03fda22a-f8a3-45e8-80dc-bf8190a22020
# 6                       0  4ec56108-97ae-4e1d-bec3-9dbc57a71bc8
# 7                       2  c12a7f1f-5dd5-44a7-8864-e7028e6ba3ed
# 8                       0  5a6d40fb-f37a-415d-bae6-83fd66bb3322
# 9                       7  01ba3f18-8cbf-4b68-8348-547e571ed939
#
#   game.pitching.win.jersey_number game.pitching.win.last_name  \
# 0                              62                    Quintana
# 1                              65                    Gallegos
# 2                              29                  Samardzija
# 3                              35                      Brooks
# 4                              55                  Stephenson
# 5                              32                        Matz
# 6                              64                      Walden
# 7                              65                     Brennan
# 8                              57                      Bieber
# 9                              34                     Stammen
#
#    game.pitching.win.loss game.pitching.win.position  \
# 0                       1                          P
# 1                       0                          P
# 2                       0                          P
# 3                       1                          P
# 4                       0                          P
# 5                       0                          P
# 6                       0                          P
# 7                       0                          P
# 8                       0                          P
# 9                       0                          P
#
#   game.pitching.win.preferred_name game.pitching.win.primary_position  \
# 0                             José                                 SP
# 1                         Giovanny                                 RP
# 2                             Jeff                                 SP
# 3                            Aaron                                 RP
# 4                           Robert                                 RP
# 5                           Steven                                 SP
# 6                           Marcus                                 RP
# 7                          Brandon                                 RP
# 8                            Shane                                 SP
# 9                            Craig                                 RP
#
#    game.pitching.win.save game.pitching.win.status  game.pitching.win.win  \
# 0                       0                        A                      1
# 1                       0                        A                      1
# 2                       0                        A                      1
# 3                       0                        A                      2
# 4                       0                        A                      1
# 5                       0                        A                      1
# 6                       0                        A                      2
# 7                       0                        A                      1
# 8                       0                        A                      1
# 9                       0                        A                      1
#
#               game.scheduled game.status         game.venue.address  \
# 0  2019-04-11T23:35:00+00:00      closed   1060 West Addison Street
# 1  2019-04-11T17:15:00+00:00      closed           700 Clark Street
# 2  2019-04-12T01:45:00+00:00      closed       24 Willie Mays Plaza
# 3  2019-04-11T16:35:00+00:00      closed     333 West Camden Street
# 4  2019-04-11T16:35:00+00:00      closed        100 Joe Nuxhall Way
# 5  2019-04-11T23:20:00+00:00      closed         755 Battery Avenue
# 6  2019-04-11T23:10:00+00:00      closed               4 Yawkey Way
# 7  2019-04-11T17:15:00+00:00      closed              One Royal Way
# 8  2019-04-11T17:10:00+00:00      closed       2100 Woodward Avenue
# 9  2019-04-12T01:40:00+00:00      closed  401 East Jefferson Street
#
#    game.venue.capacity game.venue.city game.venue.country  \
# 0                41649         Chicago                USA
# 1                45538       St. Louis                USA
# 2                41915   San Francisco                USA
# 3                45971       Baltimore                USA
# 4                42319      Cincinnati                USA
# 5                41149         Atlanta                USA
# 6                37731          Boston                USA
# 7                37903     Kansas City                USA
# 8                41297         Detroit                USA
# 9                48519         Phoenix                USA
#
#   game.venue.field_orientation                         game.venue.id  \
# 0                           NE  53f8eb0d-a361-4a7a-930b-2f8735ea0698
# 1                           NE  83cc591a-1096-4383-a6ca-e2bd6f8db629
# 2                            E  2d7542f5-7b80-49f7-9b24-c53ffdc75af6
# 3                           NE  434aa63c-1049-4a54-a6bc-3790c7772ee1
# 4                           SE  f102d8fb-de67-4b86-9053-8b55f578d45c
# 5                            S  3ca8b577-5844-42ed-81a5-bd5d5cbe350c
# 6                           NE  b27b0dc5-c2c5-401d-b8b9-a6a2dbc225e5
# 7                           NE  6fca95c9-7f2c-4acb-a9f3-02ef96340d2a
# 8                           SE  ef9a5eef-06c6-4963-ac70-7fd02c8c8d42
# 9                            N  bf05de0d-7ced-4a19-8e17-2bbd985f8a92
#
#   game.venue.location.lat game.venue.location.lng game.venue.market  \
# 0              41.9474473             -87.6560538           Chicago
# 1              38.6226441             -90.1928125         St. Louis
# 2              37.7784199            -122.3906212     San Francisco
# 3              39.2840361              -76.619919         Baltimore
# 4               39.097736             -84.5084966        Cincinnati
# 5              33.8877057             -84.4710917           Atlanta
# 6       42.34584359999999      -71.09878189999999            Boston
# 7               39.051465      -94.48028889999999       Kansas City
# 8              42.3391886      -83.04947829999999           Detroit
# 9              33.4453626            -112.0674961           Arizona
#
#                game.venue.name game.venue.stadium_type game.venue.state  \
# 0                Wrigley Field                 outdoor               IL
# 1                Busch Stadium                 outdoor               MO
# 2                  Oracle Park                 outdoor               CA
# 3  Oriole Park at Camden Yards                 outdoor               MD
# 4     Great American Ball Park                 outdoor               OH
# 5                SunTrust Park                 outdoor               GA
# 6                  Fenway Park                 outdoor               MA
# 7             Kauffman Stadium                 outdoor               MO
# 8                Comerica Park                 outdoor               MI
# 9                  Chase Field             retractable               AZ
#
#   game.venue.surface game.venue.zip  \
# 0              grass          60613
# 1              grass          63102
# 2              grass          94107
# 3              grass          21201
# 4              grass          45202
# 5              grass          30339
# 6              grass          02215
# 7              grass          64129
# 8              grass          48226
# 9              grass          85004
#
#    game.weather.current_conditions.cloud_cover  \
# 0                                          100
# 1                                            0
# 2                                           75
# 3                                          100
# 4                                            0
# 5                                           75
# 6                                           75
# 7                                           75
# 8                                            0
# 9                                          100
#
#     game.weather.current_conditions.condition  \
# 0  Thunderstorm In Vicinity, Light Rain, Mist
# 1                                       Sunny
# 2                               Partly cloudy
# 3                                    Overcast
# 4                                       Sunny
# 5                               Partly cloudy
# 6                               Partly cloudy
# 7                               Partly cloudy
# 8                                       Sunny
# 9                                    Overcast
#
#    game.weather.current_conditions.dew_point_f  \
# 0                                           44
# 1                                           50
# 2                                           45
# 3                                           37
# 4                                           55
# 5                                           57
# 6                                           29
# 7                                           32
# 8                                           28
# 9                                           21
#
#    game.weather.current_conditions.humidity  \
# 0                                        86
# 1                                        35
# 2                                        64
# 3                                        51
# 4                                        42
# 5                                        58
# 6                                        52
# 7                                        41
# 8                                        49
# 9                                        16
#
#   game.weather.current_conditions.obs_time  \
# 0                 2019-04-12T03:17:21.000Z
# 1                 2019-04-11T20:21:50.000Z
# 2                 2019-04-12T04:15:27.000Z
# 3                 2019-04-11T19:19:50.000Z
# 4                 2019-04-11T19:23:07.000Z
# 5                 2019-04-12T02:30:11.000Z
# 6                 2019-04-12T02:12:39.000Z
# 7                 2019-04-11T20:35:36.000Z
# 8                 2019-04-11T19:53:22.000Z
# 9                 2019-04-12T04:39:02.000Z
#
#    game.weather.current_conditions.temp_f  \
# 0                                      48
# 1                                      80
# 2                                      57
# 3                                      56
# 4                                      81
# 5                                      73
# 6                                      47
# 7                                      55
# 8                                      46
# 9                                      70
#
#   game.weather.current_conditions.wind.direction  \
# 0                                            NNE
# 1                                              S
# 2                                             NW
# 3                                            ESE
# 4                                              S
# 5                                            ESE
# 6                                              S
# 7                                             SW
# 8                                              E
# 9                                             SW
#
#    game.weather.current_conditions.wind.speed_mph  \
# 0                                              14
# 1                                              19
# 2                                              11
# 3                                              11
# 4                                              14
# 5                                              11
# 6                                              11
# 7                                              16
# 8                                              21
# 9                                               8
#
#    game.weather.forecast.cloud_cover game.weather.forecast.condition  \
# 0                                100                        Overcast
# 1                                  0                           Sunny
# 2                                 29                   Partly cloudy
# 3                                100                        Overcast
# 4                                  0                           Sunny
# 5                                 75                   Partly cloudy
# 6                                 75                   Partly cloudy
# 7                                100                        Overcast
# 8                                  0                           Sunny
# 9                                100                        Overcast
#
#    game.weather.forecast.dew_point_f  game.weather.forecast.humidity  \
# 0                                 40                              66
# 1                                 51                              45
# 2                                 44                              66
# 3                                 37                              51
# 4                                 55                              47
# 5                                 54                              45
# 6                                 29                              52
# 7                                 36                              53
# 8                                 28                              57
# 9                                 16                              12
#
#   game.weather.forecast.obs_time  game.weather.forecast.temp_f  \
# 0       2019-04-12T01:33:04.000Z                            52
# 1       2019-04-11T17:33:04.000Z                            74
# 2       2019-04-11T11:38:11.000Z                            56
# 3       2019-04-11T18:44:18.000Z                            56
# 4       2019-04-11T19:01:22.000Z                            77
# 5       2019-04-12T00:51:19.000Z                            77
# 6       2019-04-12T01:52:15.000Z                            47
# 7       2019-04-11T17:22:35.000Z                            54
# 8       2019-04-11T18:03:08.000Z                            42
# 9       2019-04-12T03:18:16.000Z                            72
#
#   game.weather.forecast.wind.direction  game.weather.forecast.wind.speed_mph
# 0                                  ENE                                    12
# 1                                    S                                    17
# 2                                   NW                                    20
# 3                                  ESE                                    11
# 4                                    S                                    13
# 5                                  SSE                                     9
# 6                                    S                                    11
# 7                                  SSW                                    23
# 8                                    E                                    22
# 9                                    W                                    13

# %%
joey.shape
# Out:
# (10, 139)
